# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import dicom as pdicom
import os
import scipy.ndimage
import matplotlib.pyplot as plt
import glob
import cv2
import mahotas as mh
import Augmentor
import tensorflow as tf
import matplotlib.image as mpimg


#from skimage import measure, morphology
#from mpl_toolkits.mplot3d.art3d import Poly3DCollection
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
hr={}

labels_df= pd.read_csv('calc_case_description_test_set.csv',index_col=False)
labels_df.index+=1
labels_df['image file path']='DOI/'+labels_df['image file path']
labels_df['cropped image file path']='DOI/'+labels_df['cropped image file path'].str[:-1]
labels_df['ROI mask file path']='DOI/'+labels_df['ROI mask file path']
print('computing..')    
def ff(x):
    img=pdicom.read_file(x)
    imgpx=((img.pixel_array/65535)*255).astype(np.uint8) #compute haralick features 
    #img4=cv2.resize(imgpx,(100,100)).astype(np.uint8)
    kernel = np.ones((5,5),np.float32)/25
    dilation = cv2.dilate(imgpx,kernel,iterations = 1)
    dst = cv2.filter2D(dilation,-1,kernel)
    return(mh.features.haralick(dst).mean(0))

labels_df['haralick for region of interest '] = labels_df['ROI mask file path'].map(ff)
print('STAGE 1 DONE')
#labels_df['haralick for actual breast images '] = labels_df['image file path'].map(ff)
#print('STAGE 2 DONE')
# Out:
# computing..
# STAGE 1 DONE

# %%
img = []
imgpx = []
img4 = []
for i in range(1,20):
    
    img=pdicom.read_file(labels_df['image file path'][i])
    imgpx=((img.pixel_array/65535)*255).astype(np.uint8)  
    #img4=cv2.resize(imgpx,(100,100)).astype(np.uint8)
    kernel = np.ones((5,5),np.float32)/25
   
    
    
    #dilation = cv2.dilate(imgpx,kernel,iterations = 1)
    #dst = cv2.filter2D(dilation,-1,kernel)
    #median = cv2.medianBlur(dst,5)
    #blur = cv2.GaussianBlur(median,(5,5),0)
  
    n=res.sample()
    n_labels=test['pathology'].tolist()
    plt.subplot(121),plt.imshow(imgpx),plt.title('Original')
    print (n_labels[i])
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(dst),plt.title('Processed')
    plt.xticks([]), plt.yticks([])
    plt.show()
# Out:
#   File "<ipython-input-21-7f3b81a5af1f>", line 13
#     python main.py ./labels_df['image file path'][i] fliph flipv
#               ^
# SyntaxError: invalid syntax

# %%
sav=labels_df  #make a copy of the "fixed" dataframe 
res=labels_df[['left or right breast','image view','pathology','ROI mask file path',]][labels_df['pathology']!='BENIGN_WITHOUT_CALLBACK']
res  #res has only features we need
# Out:
#     left or right breast image view  pathology  \
# 1                   LEFT         CC     BENIGN
# 2                   LEFT        MLO     BENIGN
# 15                 RIGHT         CC     BENIGN
# 16                 RIGHT        MLO     BENIGN
# 17                 RIGHT         CC  MALIGNANT
# 18                 RIGHT        MLO  MALIGNANT
# 19                  LEFT        MLO     BENIGN
# 28                  LEFT         CC     BENIGN
# 29                  LEFT        MLO     BENIGN
# 30                 RIGHT        MLO  MALIGNANT
# 31                  LEFT         CC     BENIGN
# 32                  LEFT        MLO     BENIGN
# 33                 RIGHT         CC  MALIGNANT
# 34                  LEFT         CC     BENIGN
# 35                  LEFT        MLO     BENIGN
# 36                  LEFT         CC     BENIGN
# 37                  LEFT        MLO     BENIGN
# 38                 RIGHT         CC  MALIGNANT
# 39                 RIGHT        MLO  MALIGNANT
# 45                  LEFT        MLO     BENIGN
# 46                 RIGHT        MLO  MALIGNANT
# 47                 RIGHT        MLO     BENIGN
# 48                 RIGHT         CC     BENIGN
# 49                 RIGHT        MLO     BENIGN
# 50                  LEFT        MLO  MALIGNANT
# 51                 RIGHT         CC  MALIGNANT
# 52                 RIGHT        MLO  MALIGNANT
# 53                  LEFT        MLO     BENIGN
# 54                 RIGHT        MLO     BENIGN
# 55                  LEFT         CC     BENIGN
# ..                   ...        ...        ...
# 297                 LEFT         CC     BENIGN
# 298                 LEFT        MLO     BENIGN
# 299                RIGHT         CC  MALIGNANT
# 300                RIGHT        MLO  MALIGNANT
# 301                 LEFT         CC  MALIGNANT
# 302                 LEFT        MLO  MALIGNANT
# 303                 LEFT         CC  MALIGNANT
# 304                 LEFT        MLO  MALIGNANT
# 305                RIGHT         CC     BENIGN
# 306                RIGHT        MLO     BENIGN
# 307                 LEFT         CC     BENIGN
# 308                 LEFT        MLO     BENIGN
# 309                RIGHT         CC  MALIGNANT
# 310                RIGHT        MLO  MALIGNANT
# 311                 LEFT         CC  MALIGNANT
# 312                 LEFT        MLO  MALIGNANT
# 313                 LEFT         CC  MALIGNANT
# 314                 LEFT        MLO  MALIGNANT
# 315                RIGHT         CC  MALIGNANT
# 316                RIGHT        MLO  MALIGNANT
# 317                RIGHT         CC  MALIGNANT
# 318                RIGHT        MLO  MALIGNANT
# 319                 LEFT         CC  MALIGNANT
# 320                 LEFT        MLO  MALIGNANT
# 321                RIGHT         CC  MALIGNANT
# 322                RIGHT        MLO  MALIGNANT
# 323                RIGHT         CC     BENIGN
# 324                RIGHT        MLO     BENIGN
# 325                RIGHT         CC  MALIGNANT
# 326                RIGHT        MLO  MALIGNANT
#
#                                     ROI mask file path
# 1    DOI/Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.95...
# 2    DOI/Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9...
# 15   DOI/Calc-Test_P_00100_RIGHT_CC_1/1.3.6.1.4.1.9...
# 16   DOI/Calc-Test_P_00100_RIGHT_MLO_1/1.3.6.1.4.1....
# 17   DOI/Calc-Test_P_00127_RIGHT_CC_1/1.3.6.1.4.1.9...
# 18   DOI/Calc-Test_P_00127_RIGHT_MLO_1/1.3.6.1.4.1....
# 19   DOI/Calc-Test_P_00132_LEFT_MLO_1/1.3.6.1.4.1.9...
# 28   DOI/Calc-Test_P_00141_LEFT_CC_1/1.3.6.1.4.1.95...
# 29   DOI/Calc-Test_P_00141_LEFT_MLO_1/1.3.6.1.4.1.9...
# 30   DOI/Calc-Test_P_00150_RIGHT_MLO_1/1.3.6.1.4.1....
# 31   DOI/Calc-Test_P_00163_LEFT_CC_1/1.3.6.1.4.1.95...
# 32   DOI/Calc-Test_P_00163_LEFT_MLO_1/1.3.6.1.4.1.9...
# 33   DOI/Calc-Test_P_00164_RIGHT_CC_1/1.3.6.1.4.1.9...
# 34   DOI/Calc-Test_P_00180_LEFT_CC_1/1.3.6.1.4.1.95...
# 35   DOI/Calc-Test_P_00180_LEFT_MLO_1/1.3.6.1.4.1.9...
# 36   DOI/Calc-Test_P_00195_LEFT_CC_1/1.3.6.1.4.1.95...
# 37   DOI/Calc-Test_P_00195_LEFT_MLO_1/1.3.6.1.4.1.9...
# 38   DOI/Calc-Test_P_00202_RIGHT_CC_2/1.3.6.1.4.1.9...
# 39   DOI/Calc-Test_P_00202_RIGHT_MLO_2/1.3.6.1.4.1....
# 45   DOI/Calc-Test_P_00223_LEFT_MLO_1/1.3.6.1.4.1.9...
# 46   DOI/Calc-Test_P_00244_RIGHT_MLO_1/1.3.6.1.4.1....
# 47   DOI/Calc-Test_P_00246_RIGHT_MLO_1/1.3.6.1.4.1....
# 48   DOI/Calc-Test_P_00257_RIGHT_CC_1/1.3.6.1.4.1.9...
# 49   DOI/Calc-Test_P_00257_RIGHT_MLO_1/1.3.6.1.4.1....
# 50   DOI/Calc-Test_P_00299_LEFT_MLO_1/1.3.6.1.4.1.9...
# 51   DOI/Calc-Test_P_00299_RIGHT_CC_1/1.3.6.1.4.1.9...
# 52   DOI/Calc-Test_P_00299_RIGHT_MLO_1/1.3.6.1.4.1....
# 53   DOI/Calc-Test_P_00315_LEFT_MLO_1/1.3.6.1.4.1.9...
# 54   DOI/Calc-Test_P_00325_RIGHT_MLO_1/1.3.6.1.4.1....
# 55   DOI/Calc-Test_P_00331_LEFT_CC_1/1.3.6.1.4.1.95...
# ..                                                 ...
# 297  DOI/Calc-Test_P_01882_LEFT_CC_1/1.3.6.1.4.1.95...
# 298  DOI/Calc-Test_P_01882_LEFT_MLO_1/1.3.6.1.4.1.9...
# 299  DOI/Calc-Test_P_01883_RIGHT_CC_1/1.3.6.1.4.1.9...
# 300  DOI/Calc-Test_P_01883_RIGHT_MLO_1/1.3.6.1.4.1....
# 301  DOI/Calc-Test_P_02102_LEFT_CC_1/1.3.6.1.4.1.95...
# 302  DOI/Calc-Test_P_02102_LEFT_MLO_1/1.3.6.1.4.1.9...
# 303  DOI/Calc-Test_P_02139_LEFT_CC_1/1.3.6.1.4.1.95...
# 304  DOI/Calc-Test_P_02139_LEFT_MLO_1/1.3.6.1.4.1.9...
# 305  DOI/Calc-Test_P_02153_RIGHT_CC_1/1.3.6.1.4.1.9...
# 306  DOI/Calc-Test_P_02153_RIGHT_MLO_1/1.3.6.1.4.1....
# 307  DOI/Calc-Test_P_02159_LEFT_CC_1/1.3.6.1.4.1.95...
# 308  DOI/Calc-Test_P_02159_LEFT_MLO_1/1.3.6.1.4.1.9...
# 309  DOI/Calc-Test_P_02176_RIGHT_CC_1/1.3.6.1.4.1.9...
# 310  DOI/Calc-Test_P_02176_RIGHT_MLO_1/1.3.6.1.4.1....
# 311  DOI/Calc-Test_P_02198_LEFT_CC_1/1.3.6.1.4.1.95...
# 312  DOI/Calc-Test_P_02198_LEFT_MLO_1/1.3.6.1.4.1.9...
# 313  DOI/Calc-Test_P_02275_LEFT_CC_1/1.3.6.1.4.1.95...
# 314  DOI/Calc-Test_P_02275_LEFT_MLO_1/1.3.6.1.4.1.9...
# 315  DOI/Calc-Test_P_02418_RIGHT_CC_1/1.3.6.1.4.1.9...
# 316  DOI/Calc-Test_P_02418_RIGHT_MLO_1/1.3.6.1.4.1....
# 317  DOI/Calc-Test_P_02420_RIGHT_CC_1/1.3.6.1.4.1.9...
# 318  DOI/Calc-Test_P_02420_RIGHT_MLO_1/1.3.6.1.4.1....
# 319  DOI/Calc-Test_P_02432_LEFT_CC_1/1.3.6.1.4.1.95...
# 320  DOI/Calc-Test_P_02432_LEFT_MLO_1/1.3.6.1.4.1.9...
# 321  DOI/Calc-Test_P_02464_RIGHT_CC_1/1.3.6.1.4.1.9...
# 322  DOI/Calc-Test_P_02464_RIGHT_MLO_1/1.3.6.1.4.1....
# 323  DOI/Calc-Test_P_02498_RIGHT_CC_1/1.3.6.1.4.1.9...
# 324  DOI/Calc-Test_P_02498_RIGHT_MLO_1/1.3.6.1.4.1....
# 325  DOI/Calc-Test_P_02501_RIGHT_CC_1/1.3.6.1.4.1.9...
# 326  DOI/Calc-Test_P_02501_RIGHT_MLO_1/1.3.6.1.4.1....
#
# [259 rows x 4 columns]

# %%
#training and testing split 
train=res.sample(frac=0.8,random_state=100)
test=res.drop(train.index)
test_labels=test['pathology'].tolist()
train_labels=train['pathology'].tolist()
#test_features=test['haralick for region of interest '].tolist()
#train_features=train['haralick for region of interest '].tolist()
print(len(test))
print(len(train))
# Out:
# 52
# 207

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import cv2

import numpy as np
# %matplotlib inline
import matplotlib.image as mpimg

# %%
def augment_brightness_camera_images(image):
    #image1 = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)
    random_bright = .25+np.random.uniform()
    #print(random_bright)
    image[:,2] = image[:,2]*random_bright
    #image1 = cv2.cvtColor(image1,cv2.COLOR_HSV2RGB)
    return image

def transform_image(img,ang_range,shear_range,trans_range,brightness=0):
    '''
    This function transforms images to generate new images.
    The function takes in following arguments,
    1- Image
    2- ang_range: Range of angles for rotation
    3- shear_range: Range of values to apply affine transform to
    4- trans_range: Range of values to apply translations over.

    A Random uniform distribution is used to generate different parameters for transformation

    '''
    # Rotation

    ang_rot = np.random.uniform(ang_range)-ang_range/2
    rows,cols = img.shape    
    Rot_M = cv2.getRotationMatrix2D((cols/2,rows/2),ang_rot,1)

    # Translation
    tr_x = trans_range*np.random.uniform()-trans_range/2
    tr_y = trans_range*np.random.uniform()-trans_range/2
    Trans_M = np.float32([[1,0,tr_x],[0,1,tr_y]])

    # Shear
    pts1 = np.float32([[5,5],[20,5],[5,20]])

    pt1 = 5+shear_range*np.random.uniform()-shear_range/2
    pt2 = 20+shear_range*np.random.uniform()-shear_range/2

    # Brightness


    pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])

    shear_M = cv2.getAffineTransform(pts1,pts2)

    img = cv2.warpAffine(img,Rot_M,(cols,rows))
    img = cv2.warpAffine(img,Trans_M,(cols,rows))
    img = cv2.warpAffine(img,shear_M,(cols,rows))

    if brightness == 1:
        img = augment_brightness_camera_images(img)

    return img

# %%
img = pdicom.read_file(labels_df['image file path'][1])
image=((img.pixel_array/65535)*255).astype(np.uint8)  
#img4=cv2.resize(imgpx,(100,100)).astype(np.uint8)
#kernel = np.ones((5,5),np.float32)/25
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 3015.5, 4615.5, -0.5)

# %%
img4=cv2.resize(image,(224,224)).astype(np.uint8)
plt.imshow(img4)

# %%
img4.shape
# Out:
# (224, 224)

# %%
#image = mpimg.imread('stopsign.jpg')
#plt.imshow(image);
#plt.axis('off');

# %%
gs1 = gridspec.GridSpec(10, 10)
gs1.update(wspace=0.01, hspace=0.02) # set the spacing between axes.
plt.figure(figsize=(12,12))
for i in range(100):
    ax1 = plt.subplot(gs1[i])
    ax1.set_xticklabels([])
    ax1.set_yticklabels([])
    ax1.set_aspect('equal')
    img = transform_image(image,20,10,5,brightness=1)

    plt.subplot(10,10,i+1)
    plt.imshow(img)
    plt.axis('off')

plt.show()

# %%
IMAGE_SIZE = 224


def rotate_images(X_imgs):
    X_rotate = []
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, shape = (IMAGE_SIZE, IMAGE_SIZE, 3))
    k = tf.placeholder(tf.int32)
    tf_img = tf.image.rot90(X, k = k)
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for img in X_imgs:
            for i in range(3):  # Rotation at 90, 180 and 270 degrees
                rotated_img = sess.run(tf_img, feed_dict = {X: img, k: i + 1})
                X_rotate.append(rotated_img)
        
    X_rotate = np.array(X_rotate, dtype = np.float32)
    return X_rotate
	
rotated_imgs = rotate_images(img4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in merge_with(self, other)
#     578       try:
# --> 579         self.assert_same_rank(other)
#     580         new_dims = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in assert_same_rank(self, other)
#     623         raise ValueError("Shapes %s and %s must have the same rank" % (self,
# --> 624                                                                        other))
#     625
#
# ValueError: Shapes (224, 224) and (?, ?, ?) must have the same rank
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in with_rank(self, rank)
#     653     try:
# --> 654       return self.merge_with(unknown_shape(ndims=rank))
#     655     except ValueError:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in merge_with(self, other)
#     584       except ValueError:
# --> 585         raise ValueError("Shapes %s and %s are not compatible" % (self, other))
#     586
#
# ValueError: Shapes (224, 224) and (?, ?, ?) are not compatible
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\image_ops_impl.py in _Check3DImage(image, require_static)
#     128   try:
# --> 129     image_shape = image.get_shape().with_rank(3)
#     130   except ValueError:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in with_rank(self, rank)
#     655     except ValueError:
# --> 656       raise ValueError("Shape %s must have rank %d" % (self, rank))
#     657
#
# ValueError: Shape (224, 224) must have rank 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-08bdf4bf307e> in <module>()
#      18     return X_rotate
#      19
# ---> 20 rotated_imgs = rotate_images(img4)
#
# <ipython-input-80-08bdf4bf307e> in rotate_images(X_imgs)
#       7     X = tf.placeholder(tf.float32, shape = (IMAGE_SIZE, IMAGE_SIZE))
#       8     k = tf.placeholder(tf.int32)
# ----> 9     tf_img = tf.image.rot90(X, k = k)
#      10     with tf.Session() as sess:
#      11         sess.run(tf.global_variables_initializer())
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\image_ops_impl.py in rot90(image, k, name)
#     353   with ops.name_scope(name, 'rot90', [image, k]) as scope:
#     354     image = ops.convert_to_tensor(image, name='image')
# --> 355     image = _Assert3DImage(image)
#     356     k = ops.convert_to_tensor(k, dtype=dtypes.int32, name='k')
#     357     k.get_shape().assert_has_rank(0)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\image_ops_impl.py in _Assert3DImage(image)
#     165     """
#     166   return control_flow_ops.with_dependencies(
# --> 167       _Check3DImage(image, require_static=False), image)
#     168
#     169
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\image_ops_impl.py in _Check3DImage(image, require_static)
#     130   except ValueError:
#     131     raise ValueError(
# --> 132         "'image' (shape %s) must be three-dimensional." % image.shape)
#     133   if require_static and not image_shape.is_fully_defined():
#     134     raise ValueError("'image' (shape %s) must be fully defined." % image_shape)
#
# ValueError: 'image' (shape (224, 224)) must be three-dimensional.

# %%
from skimage.transform import rotate
from skimage.transform import resize


def rotate_img(img,h,w,name):
    from skimage.io import imsave
    temp=np.zeros((0,h*w),dtype=np.uint8)
    img = resize(img, (h,w),mode='reflect')
    rads = [0,180 ] #increase as needed.
    n=0
    for i in rads:
        img_r = rotate(img,i)

        try:
            plt.imshow(img_r)
            plt.show()
            #imsave( filename , img_r)
        except:
            print("low contrast")
        n+=1

# %%
h=224
w=224
rotate_img(img4,h,w,'test')

# %%
import numpy as np
import os
import cv2
def noisy(noise_typ,image):
    
    if noise_typ == "gauss":
        row,col= image.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col))
        gauss = gauss.reshape(row,col,)
        noisy = image + gauss
        return noisy
   
    elif noise_typ == "s&p":
        row,col= image.shape
        s_vs_p = 0.5
        amount = 0.004
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(amount * image.size * s_vs_p)
        coords = [np.random.randint(0, i - 1, int(num_salt))
                  for i in image.shape]
        out[coords] = 1

        
       # Pepper mode
        num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in image.shape]
        out[coords] = 0
        return out
    
    elif noise_typ == "poisson":
        vals = len(np.unique(image))
        vals = 2 ** np.ceil(np.log2(vals))
        noisy = np.random.poisson(image * vals) / float(vals)
        return noisy
  
    elif noise_typ =="speckle":
        row,col = image.shape
        gauss = np.random.randn(row,col)
        gauss = gauss.reshape(row,col)        
        noisy = image + image * gauss
        return noisy

# %%
noise_image = noisy("gauss",img4)
plt.subplot(1,2,1)
plt.imshow(noise_image)
plt.subplot(1,2,2)
plt.imshow(img4)
plt.show()
